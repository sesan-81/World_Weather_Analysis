# %%
#Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# %%
weather_api_key = "51b0a8acb15bb7b30d0465830b5882b8"

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 789

# %%
###### Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | lasa
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | sisimiut
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | belaya gora
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 1 | flinders
# Processing Record 13 of Set 1 | linhares
# Processing Record 14 of Set 1 | scarborough
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | torbay
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | galt
# Processing Record 25 of Set 1 | la paz
# Processing Record 26 of Set 1 | hof
# Processing Record 27 of Set 1 | adrar
# Processing Record 28 of Set 1 | kidal
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | vardo
# Processing Record 31 of Set 1 | barcelos
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | teknaf
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | callaway
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | mahibadhoo
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | yasnyy
# Processing Record 46 of Set 1 | sechura
# Processing Record 47 of Set 1 | tamiahua
# Processing Record 48 of Set 1 | labuhan
# Processing Record 49 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 1 | marihatag
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | port hedland
# Processing Record 3 of Set 2 | half moon bay
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | college
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | paraopeba
# Processing Record 9 of Set 2 | pereira
# Processing Record 10 of Set 2 | meulaboh
# Processing Record 11 of Set 2 | carballo
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | samarai
# Processing Record 14 of Set 2 | morondava
# Processing Record 15 of Set 2 | berikulskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | strezhevoy
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 2 | ferme-neuve
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | manokwari
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | bengkulu
# Processing Record 29 of Set 2 | leticia
# Processing Record 30 of Set 2 | ambovombe
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | harer
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | labis
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | arlit
# Processing Record 39 of Set 2 | rawson
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | chara
# Processing Record 42 of Set 2 | berea
# Processing Record 43 of Set 2 | mayo
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | matara
# Processing Record 47 of Set 2 | coihaique
# Processing Record 48 of Set 2 | moose factory
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | teguise
# Processing Record 4 of Set 3 | ambon
# Processing Record 5 of Set 3 | salinopolis
# Processing Record 6 of Set 3 | sinnamary
# Processing Record 7 of Set 3 | san jose
# Processing Record 8 of Set 3 | doha
# Processing Record 9 of Set 3 | jawhar
# Processing Record 10 of Set 3 | talcahuano
# Processing Record 11 of Set 3 | mehran
# Processing Record 12 of Set 3 | kodinsk
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | banjar
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | pangnirtung
# Processing Record 18 of Set 3 | mpanda
# Processing Record 19 of Set 3 | ishinomaki
# Processing Record 20 of Set 3 | belluno
# Processing Record 21 of Set 3 | zaysan
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | narasaraopet
# Processing Record 24 of Set 3 | bertoua
# Processing Record 25 of Set 3 | saint anthony
# Processing Record 26 of Set 3 | mandalgovi
# Processing Record 27 of Set 3 | manavalakurichi
# Processing Record 28 of Set 3 | trapani
# Processing Record 29 of Set 3 | hoshcha
# Processing Record 30 of Set 3 | emerald
# Processing Record 31 of Set 3 | yaan
# Processing Record 32 of Set 3 | concordia
# Processing Record 33 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 3 | warrnambool
# Processing Record 35 of Set 3 | omboue
# Processing Record 36 of Set 3 | marevo
# Processing Record 37 of Set 3 | padang
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | kandalaksha
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | velingara
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | arraial do cabo
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | pawai
# Processing Record 47 of Set 3 | quatre cocos
# Processing Record 48 of Set 3 | ahuimanu
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | xai-xai
# Processing Record 1 of Set 4 | batagay-alyta
# Processing Record 2 of Set 4 | havoysund
# Processing Record 3 of Set 4 | koutiala
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | fare
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | polyanka
# Processing Record 9 of Set 4 | qaanaaq
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | murray
# Processing Record 12 of Set 4 | tual
# Processing Record 13 of Set 4 | tuktoyaktuk
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | marawi
# Processing Record 17 of Set 4 | pozo colorado
# Processing Record 18 of Set 4 | codrington
# Processing Record 19 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 4 | sinop
# Processing Record 21 of Set 4 | luang prabang
# Processing Record 22 of Set 4 | karakose
# City not found. Skipping...
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | sistranda
# Processing Record 25 of Set 4 | xining
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | msanga
# Processing Record 28 of Set 4 | campbell river
# Processing Record 29 of Set 4 | atar
# Processing Record 30 of Set 4 | wairoa
# Processing Record 31 of Set 4 | sambava
# Processing Record 32 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 4 | le port
# Processing Record 34 of Set 4 | uglich
# Processing Record 35 of Set 4 | celestun
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 38 of Set 4 | ambilobe
# Processing Record 39 of Set 4 | arroyo
# Processing Record 40 of Set 4 | meridian
# Processing Record 41 of Set 4 | honningsvag
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | shirokiy
# Processing Record 44 of Set 4 | nuevo progreso
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | beyneu
# Processing Record 47 of Set 4 | valparaiso
# Processing Record 48 of Set 4 | todos santos
# Processing Record 49 of Set 4 | upernavik
# Processing Record 50 of Set 4 | cayenne
# Processing Record 1 of Set 5 | urengoy
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | malakal
# Processing Record 4 of Set 5 | kudahuvadhoo
# Processing Record 5 of Set 5 | pueblo
# Processing Record 6 of Set 5 | sicula
# Processing Record 7 of Set 5 | belgaum
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | tandil
# Processing Record 10 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 5 | bowen
# Processing Record 12 of Set 5 | tasiilaq
# Processing Record 13 of Set 5 | nuuk
# Processing Record 14 of Set 5 | waingapu
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 5 | wilmington
# Processing Record 18 of Set 5 | hithadhoo
# Processing Record 19 of Set 5 | wapi pathum
# Processing Record 20 of Set 5 | belle fourche
# Processing Record 21 of Set 5 | fortuna
# Processing Record 22 of Set 5 | pitea
# Processing Record 23 of Set 5 | nantucket
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | bjornevatn
# Processing Record 27 of Set 5 | plerin
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | bonavista
# Processing Record 30 of Set 5 | vila
# Processing Record 31 of Set 5 | pombas
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | eyl
# Processing Record 34 of Set 5 | alice springs
# Processing Record 35 of Set 5 | bairiki
# Processing Record 36 of Set 5 | pontianak
# Processing Record 37 of Set 5 | sarankhola
# Processing Record 38 of Set 5 | praia
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | acapulco
# Processing Record 41 of Set 5 | guasdualito
# Processing Record 42 of Set 5 | jizan
# Processing Record 43 of Set 5 | mizdah
# Processing Record 44 of Set 5 | broome
# Processing Record 45 of Set 5 | san matias
# Processing Record 46 of Set 5 | huarmey
# Processing Record 47 of Set 5 | riyadh
# Processing Record 48 of Set 5 | mabaruma
# Processing Record 49 of Set 5 | rocha
# Processing Record 50 of Set 5 | paralimni
# Processing Record 1 of Set 6 | avera
# Processing Record 2 of Set 6 | airai
# Processing Record 3 of Set 6 | harper
# Processing Record 4 of Set 6 | miracema do tocantins
# Processing Record 5 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 6 | manado
# Processing Record 7 of Set 6 | vilhena
# Processing Record 8 of Set 6 | dhaulpur
# Processing Record 9 of Set 6 | rizal
# Processing Record 10 of Set 6 | freetown
# Processing Record 11 of Set 6 | ngunguru
# Processing Record 12 of Set 6 | chernyshevskiy
# Processing Record 13 of Set 6 | chuy
# Processing Record 14 of Set 6 | broken hill
# Processing Record 15 of Set 6 | iralaya
# Processing Record 16 of Set 6 | ribeira grande
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | honiara
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | sakakah
# Processing Record 21 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 6 | mashhad
# Processing Record 23 of Set 6 | hasaki
# Processing Record 24 of Set 6 | calama
# Processing Record 25 of Set 6 | artigas
# Processing Record 26 of Set 6 | mungaoli
# Processing Record 27 of Set 6 | sukumo
# Processing Record 28 of Set 6 | phayakkhaphum phisai
# Processing Record 29 of Set 6 | malisbong
# City not found. Skipping...
# Processing Record 30 of Set 6 | shenxian
# Processing Record 31 of Set 6 | paracin
# Processing Record 32 of Set 6 | tanout
# Processing Record 33 of Set 6 | tautira
# Processing Record 34 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 6 | ogaminana
# Processing Record 36 of Set 6 | igrim
# Processing Record 37 of Set 6 | tuatapere
# Processing Record 38 of Set 6 | cap malheureux
# Processing Record 39 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 6 | dubai
# Processing Record 41 of Set 6 | alipur
# Processing Record 42 of Set 6 | batagay
# Processing Record 43 of Set 6 | labytnangi
# Processing Record 44 of Set 6 | port-gentil
# Processing Record 45 of Set 6 | kurchum
# Processing Record 46 of Set 6 | touros
# Processing Record 47 of Set 6 | berlevag
# Processing Record 48 of Set 6 | tulum
# Processing Record 49 of Set 6 | peace river
# Processing Record 50 of Set 6 | marystown
# Processing Record 1 of Set 7 | saint-joseph
# Processing Record 2 of Set 7 | raudeberg
# Processing Record 3 of Set 7 | hazorasp
# Processing Record 4 of Set 7 | pochutla
# Processing Record 5 of Set 7 | flores
# Processing Record 6 of Set 7 | rhyl
# Processing Record 7 of Set 7 | feicheng
# Processing Record 8 of Set 7 | souillac
# Processing Record 9 of Set 7 | zhigansk
# Processing Record 10 of Set 7 | grevesmuhlen
# Processing Record 11 of Set 7 | rio grande
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | ganzhou
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | santa maria
# Processing Record 16 of Set 7 | kardla
# Processing Record 17 of Set 7 | kangaatsiaq
# Processing Record 18 of Set 7 | ola
# Processing Record 19 of Set 7 | prince rupert
# Processing Record 20 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 7 | umm lajj
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | karatsu
# Processing Record 24 of Set 7 | atasu
# Processing Record 25 of Set 7 | abalak
# Processing Record 26 of Set 7 | burnie
# Processing Record 27 of Set 7 | sur
# Processing Record 28 of Set 7 | copiapo
# Processing Record 29 of Set 7 | heihe
# Processing Record 30 of Set 7 | beloha
# Processing Record 31 of Set 7 | puri
# Processing Record 32 of Set 7 | hobyo
# Processing Record 33 of Set 7 | biscarrosse
# Processing Record 34 of Set 7 | mount isa
# Processing Record 35 of Set 7 | dwarka
# Processing Record 36 of Set 7 | batticaloa
# Processing Record 37 of Set 7 | vrangel
# Processing Record 38 of Set 7 | saint-augustin
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | truth or consequences
# Processing Record 41 of Set 7 | comodoro rivadavia
# Processing Record 42 of Set 7 | hofn
# Processing Record 43 of Set 7 | rodez
# Processing Record 44 of Set 7 | saldanha
# Processing Record 45 of Set 7 | horki
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | ostrovnoy
# Processing Record 48 of Set 7 | arrecife
# Processing Record 49 of Set 7 | aden
# Processing Record 50 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 8 | teguldet
# Processing Record 2 of Set 8 | hovd
# Processing Record 3 of Set 8 | altay
# Processing Record 4 of Set 8 | asau
# Processing Record 5 of Set 8 | barbalha
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | ilhabela
# Processing Record 8 of Set 8 | verkhnevilyuysk
# Processing Record 9 of Set 8 | uige
# Processing Record 10 of Set 8 | bull savanna
# Processing Record 11 of Set 8 | mayya
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | buguruslan
# Processing Record 14 of Set 8 | mareeba
# Processing Record 15 of Set 8 | pilot butte
# Processing Record 16 of Set 8 | ibimirim
# Processing Record 17 of Set 8 | oparino
# Processing Record 18 of Set 8 | gambela
# Processing Record 19 of Set 8 | yar-sale
# Processing Record 20 of Set 8 | na wa
# Processing Record 21 of Set 8 | shache
# Processing Record 22 of Set 8 | gornyak
# Processing Record 23 of Set 8 | alta floresta
# Processing Record 24 of Set 8 | pangai
# Processing Record 25 of Set 8 | muyezerskiy
# Processing Record 26 of Set 8 | san jeronimo
# Processing Record 27 of Set 8 | machico
# Processing Record 28 of Set 8 | kaeo
# Processing Record 29 of Set 8 | pareora
# Processing Record 30 of Set 8 | wabag
# Processing Record 31 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 8 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 33 of Set 8 | itaguai
# Processing Record 34 of Set 8 | paredon
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | teya
# Processing Record 37 of Set 8 | mitchell
# Processing Record 38 of Set 8 | manta
# Processing Record 39 of Set 8 | gidole
# Processing Record 40 of Set 8 | umm kaddadah
# Processing Record 41 of Set 8 | komsomolskiy
# Processing Record 42 of Set 8 | soverato
# Processing Record 43 of Set 8 | surt
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | husavik
# Processing Record 46 of Set 8 | vanavara
# Processing Record 47 of Set 8 | liverpool
# Processing Record 48 of Set 8 | laguna
# Processing Record 49 of Set 8 | faya
# Processing Record 50 of Set 8 | villa bruzual
# Processing Record 1 of Set 9 | bosaso
# Processing Record 2 of Set 9 | pandan
# Processing Record 3 of Set 9 | contai
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | laem sing
# Processing Record 6 of Set 9 | dustlik
# Processing Record 7 of Set 9 | kurumkan
# Processing Record 8 of Set 9 | urumqi
# Processing Record 9 of Set 9 | bilibino
# Processing Record 10 of Set 9 | sterling
# Processing Record 11 of Set 9 | pisco
# Processing Record 12 of Set 9 | klamath falls
# Processing Record 13 of Set 9 | inirida
# Processing Record 14 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 9 | bouza
# Processing Record 16 of Set 9 | severo-kurilsk
# Processing Record 17 of Set 9 | saint combs
# City not found. Skipping...
# Processing Record 18 of Set 9 | neuquen
# Processing Record 19 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 9 | norwalk
# Processing Record 21 of Set 9 | narsaq
# Processing Record 22 of Set 9 | waipawa
# Processing Record 23 of Set 9 | san cristobal
# Processing Record 24 of Set 9 | amposta
# Processing Record 25 of Set 9 | port macquarie
# Processing Record 26 of Set 9 | nerchinsk
# Processing Record 27 of Set 9 | hubli
# Processing Record 28 of Set 9 | salalah
# Processing Record 29 of Set 9 | palmer
# Processing Record 30 of Set 9 | brainerd
# Processing Record 31 of Set 9 | siguiri
# Processing Record 32 of Set 9 | tazmalt
# Processing Record 33 of Set 9 | talnakh
# Processing Record 34 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 9 | sao felix do xingu
# Processing Record 36 of Set 9 | gobabis
# Processing Record 37 of Set 9 | ginda
# Processing Record 38 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 9 | marzuq
# Processing Record 40 of Set 9 | uren
# Processing Record 41 of Set 9 | gimli
# Processing Record 42 of Set 9 | malatya
# Processing Record 43 of Set 9 | neryungri
# Processing Record 44 of Set 9 | cururupu
# Processing Record 45 of Set 9 | catamarca
# Processing Record 46 of Set 9 | uribia
# Processing Record 47 of Set 9 | soloneshnoye
# Processing Record 48 of Set 9 | port hawkesbury
# Processing Record 49 of Set 9 | san rafael
# Processing Record 50 of Set 9 | sibolga
# Processing Record 1 of Set 10 | vitim
# Processing Record 2 of Set 10 | derby
# Processing Record 3 of Set 10 | togur
# Processing Record 4 of Set 10 | abu dhabi
# Processing Record 5 of Set 10 | tigil
# Processing Record 6 of Set 10 | aras
# Processing Record 7 of Set 10 | kortkeros
# Processing Record 8 of Set 10 | bethanien
# Processing Record 9 of Set 10 | sabha
# Processing Record 10 of Set 10 | phuket
# Processing Record 11 of Set 10 | geraldton
# Processing Record 12 of Set 10 | munxar
# Processing Record 13 of Set 10 | saint-michel-des-saints
# Processing Record 14 of Set 10 | zhanakorgan
# Processing Record 15 of Set 10 | northam
# Processing Record 16 of Set 10 | viedma
# Processing Record 17 of Set 10 | guerrero negro
# Processing Record 18 of Set 10 | tucuman
# Processing Record 19 of Set 10 | alugan
# Processing Record 20 of Set 10 | nizhniy baskunchak
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | birjand
# Processing Record 23 of Set 10 | buala
# Processing Record 24 of Set 10 | igarka
# Processing Record 25 of Set 10 | porgera
# Processing Record 26 of Set 10 | aksu
# Processing Record 27 of Set 10 | la ronge
# Processing Record 28 of Set 10 | abilene
# Processing Record 29 of Set 10 | galveston
# Processing Record 30 of Set 10 | ulladulla
# Processing Record 31 of Set 10 | nizhnevartovsk
# Processing Record 32 of Set 10 | pahalgam
# Processing Record 33 of Set 10 | pokhara
# Processing Record 34 of Set 10 | san policarpo
# Processing Record 35 of Set 10 | pafos
# Processing Record 36 of Set 10 | belmonte
# Processing Record 37 of Set 10 | parana
# Processing Record 38 of Set 10 | nishihara
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | thiruvananthapuram
# Processing Record 41 of Set 10 | oxbow
# Processing Record 42 of Set 10 | iwaki
# Processing Record 43 of Set 10 | tura
# Processing Record 44 of Set 10 | barguzin
# Processing Record 45 of Set 10 | stephenville
# Processing Record 46 of Set 10 | namuac
# Processing Record 47 of Set 10 | santa cruz
# Processing Record 48 of Set 10 | nong phai
# Processing Record 49 of Set 10 | szczytno
# Processing Record 50 of Set 10 | marang
# Processing Record 1 of Set 11 | aswan
# Processing Record 2 of Set 11 | lucapa
# Processing Record 3 of Set 11 | pyapon
# Processing Record 4 of Set 11 | inta
# Processing Record 5 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 11 | andenes
# Processing Record 7 of Set 11 | katsuura
# Processing Record 8 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 9 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 11 | cherrapunji
# Processing Record 11 of Set 11 | henties bay
# Processing Record 12 of Set 11 | klaksvik
# Processing Record 13 of Set 11 | lashio
# Processing Record 14 of Set 11 | leningradskiy
# Processing Record 15 of Set 11 | merauke
# Processing Record 16 of Set 11 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 11 | bose
# Processing Record 20 of Set 11 | clarence town
# Processing Record 21 of Set 11 | dolzhanskaya
# Processing Record 22 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 11 | miri
# Processing Record 24 of Set 11 | ossora
# Processing Record 25 of Set 11 | sartell
# Processing Record 26 of Set 11 | kpandae
# Processing Record 27 of Set 11 | culpeper
# Processing Record 28 of Set 11 | payo
# Processing Record 29 of Set 11 | katima mulilo
# Processing Record 30 of Set 11 | verkhnechusovskiye gorodki
# Processing Record 31 of Set 11 | pahrump
# Processing Record 32 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 11 | tenamaxtlan
# Processing Record 34 of Set 11 | yuancheng
# Processing Record 35 of Set 11 | along
# Processing Record 36 of Set 11 | carahue
# Processing Record 37 of Set 11 | sao luiz gonzaga
# Processing Record 38 of Set 11 | washington terrace
# Processing Record 39 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 11 | chulman
# Processing Record 41 of Set 11 | quesnel
# Processing Record 42 of Set 11 | srednekolymsk
# Processing Record 43 of Set 11 | sungai siput utara
# City not found. Skipping...
# Processing Record 44 of Set 11 | denpasar
# Processing Record 45 of Set 11 | sao joao da barra
# Processing Record 46 of Set 11 | turukhansk
# Processing Record 47 of Set 11 | zaraza
# Processing Record 48 of Set 11 | pathein
# Processing Record 49 of Set 11 | port-cartier
# Processing Record 50 of Set 11 | svetlyy
# Processing Record 1 of Set 12 | jos
# Processing Record 2 of Set 12 | san joaquin
# Processing Record 3 of Set 12 | ixtapa
# Processing Record 4 of Set 12 | sabzevar
# Processing Record 5 of Set 12 | bonthe
# Processing Record 6 of Set 12 | turka
# Processing Record 7 of Set 12 | maceio
# Processing Record 8 of Set 12 | slave lake
# Processing Record 9 of Set 12 | taoudenni
# Processing Record 10 of Set 12 | itarema
# Processing Record 11 of Set 12 | fatikchhari
# City not found. Skipping...
# Processing Record 12 of Set 12 | chaozhou
# Processing Record 13 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 14 of Set 12 | skagen
# Processing Record 15 of Set 12 | lisakovsk
# Processing Record 16 of Set 12 | butembo
# Processing Record 17 of Set 12 | paracuru
# Processing Record 18 of Set 12 | lamu
# Processing Record 19 of Set 12 | brunico
# Processing Record 20 of Set 12 | vila velha
# Processing Record 21 of Set 12 | qasigiannguit
# Processing Record 22 of Set 12 | khash
# Processing Record 23 of Set 12 | carlisle
# Processing Record 24 of Set 12 | satuba
# Processing Record 25 of Set 12 | khasan
# Processing Record 26 of Set 12 | san isidro
# Processing Record 27 of Set 12 | toppenish
# Processing Record 28 of Set 12 | lae
# Processing Record 29 of Set 12 | sobolevo
# Processing Record 30 of Set 12 | actopan
# Processing Record 31 of Set 12 | nyurba
# Processing Record 32 of Set 12 | aklavik
# Processing Record 33 of Set 12 | sorland
# Processing Record 34 of Set 12 | kingsport
# Processing Record 35 of Set 12 | korla
# Processing Record 36 of Set 12 | clyde river
# Processing Record 37 of Set 12 | noyabrsk
# Processing Record 38 of Set 12 | san nicolas
# Processing Record 39 of Set 12 | dukat
# Processing Record 40 of Set 12 | margate
# Processing Record 41 of Set 12 | maragogi
# Processing Record 42 of Set 12 | lahat
# Processing Record 43 of Set 12 | kenora
# Processing Record 44 of Set 12 | yumen
# Processing Record 45 of Set 12 | conakry
# Processing Record 46 of Set 12 | andros town
# Processing Record 47 of Set 12 | pulawy
# Processing Record 48 of Set 12 | kieta
# Processing Record 49 of Set 12 | saskatoon
# Processing Record 50 of Set 12 | harij
# Processing Record 1 of Set 13 | bauchi
# Processing Record 2 of Set 13 | aguimes
# Processing Record 3 of Set 13 | beringovskiy
# Processing Record 4 of Set 13 | guhagar
# Processing Record 5 of Set 13 | sept-iles
# Processing Record 6 of Set 13 | piscu
# Processing Record 7 of Set 13 | svetlogorsk
# Processing Record 8 of Set 13 | nome
# Processing Record 9 of Set 13 | port hardy
# Processing Record 10 of Set 13 | myitkyina
# Processing Record 11 of Set 13 | indramayu
# Processing Record 12 of Set 13 | santa ines
# Processing Record 13 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 13 | thinadhoo
# Processing Record 15 of Set 13 | fort nelson
# Processing Record 16 of Set 13 | pangkalanbuun
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | jogighopa
# Processing Record 19 of Set 13 | kununurra
# Processing Record 20 of Set 13 | santa rosa
# Processing Record 21 of Set 13 | hatillo
# Processing Record 22 of Set 13 | aksarka
# Processing Record 23 of Set 13 | kamariotissa
# Processing Record 24 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 13 | kosum phisai
# Processing Record 26 of Set 13 | tilichiki
# Processing Record 27 of Set 13 | salamiyah
# Processing Record 28 of Set 13 | beian
# Processing Record 29 of Set 13 | matadi
# Processing Record 30 of Set 13 | key largo
# Processing Record 31 of Set 13 | naryan-mar
# Processing Record 32 of Set 13 | robertson
# Processing Record 33 of Set 13 | roald
# Processing Record 34 of Set 13 | ukiah
# Processing Record 35 of Set 13 | erenhot
# Processing Record 36 of Set 13 | opuwo
# Processing Record 37 of Set 13 | sakaide
# Processing Record 38 of Set 13 | cape coast
# Processing Record 39 of Set 13 | syracuse
# Processing Record 40 of Set 13 | bud
# Processing Record 41 of Set 13 | hirara
# Processing Record 42 of Set 13 | quirinopolis
# Processing Record 43 of Set 13 | ulcinj
# Processing Record 44 of Set 13 | inuvik
# Processing Record 45 of Set 13 | batsfjord
# Processing Record 46 of Set 13 | gunjur
# Processing Record 47 of Set 13 | elat
# Processing Record 48 of Set 13 | garowe
# Processing Record 49 of Set 13 | roebourne
# Processing Record 50 of Set 13 | diffa
# Processing Record 1 of Set 14 | cabedelo
# Processing Record 2 of Set 14 | sao filipe
# Processing Record 3 of Set 14 | cuiaba
# Processing Record 4 of Set 14 | patiala
# Processing Record 5 of Set 14 | canatlan
# Processing Record 6 of Set 14 | menemen
# Processing Record 7 of Set 14 | lokosovo
# Processing Record 8 of Set 14 | lazaro cardenas
# Processing Record 9 of Set 14 | grindavik
# Processing Record 10 of Set 14 | hudiksvall
# Processing Record 11 of Set 14 | sorong
# Processing Record 12 of Set 14 | obo
# Processing Record 13 of Set 14 | ratnagiri
# Processing Record 14 of Set 14 | iracoubo
# Processing Record 15 of Set 14 | vestmanna
# Processing Record 16 of Set 14 | muzhi
# Processing Record 17 of Set 14 | barra dos coqueiros
# Processing Record 18 of Set 14 | lushunkou
# City not found. Skipping...
# Processing Record 19 of Set 14 | haines junction
# Processing Record 20 of Set 14 | sarkand
# Processing Record 21 of Set 14 | santa maria do suacui
# Processing Record 22 of Set 14 | carutapera
# Processing Record 23 of Set 14 | dhidhdhoo
# Processing Record 24 of Set 14 | saiha
# Processing Record 25 of Set 14 | khor
# Processing Record 26 of Set 14 | kautokeino
# Processing Record 27 of Set 14 | nizwa
# Processing Record 28 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 14 | challapata
# Processing Record 30 of Set 14 | pogranichnyy
# Processing Record 31 of Set 14 | reefton
# City not found. Skipping...
# Processing Record 32 of Set 14 | sao jose da coroa grande
# Processing Record 33 of Set 14 | kyra
# Processing Record 34 of Set 14 | karangasem
# Processing Record 35 of Set 14 | uray
# Processing Record 36 of Set 14 | san quintin
# Processing Record 37 of Set 14 | labelle
# Processing Record 38 of Set 14 | coahuayana
# Processing Record 39 of Set 14 | harare
# Processing Record 40 of Set 14 | caraballeda
# Processing Record 41 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 14 | coquimbo
# Processing Record 43 of Set 14 | provideniya
# Processing Record 44 of Set 14 | wanxian
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | peterhead
# Processing Record 47 of Set 14 | ponta do sol
# Processing Record 48 of Set 14 | bafoulabe
# Processing Record 49 of Set 14 | niceville
# Processing Record 50 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 15 | liezen
# Processing Record 2 of Set 15 | manzhouli
# Processing Record 3 of Set 15 | kambove
# Processing Record 4 of Set 15 | port lincoln
# Processing Record 5 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 6 of Set 15 | sedhiou
# Processing Record 7 of Set 15 | lianran
# Processing Record 8 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 15 | gaziantep
# Processing Record 10 of Set 15 | pingxiang
# Processing Record 11 of Set 15 | ambulu
# Processing Record 12 of Set 15 | bay roberts
# Processing Record 13 of Set 15 | kamaishi
# Processing Record 14 of Set 15 | kysyl-syr
# Processing Record 15 of Set 15 | khandyga
# Processing Record 16 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 17 of Set 15 | meadow lake
# Processing Record 18 of Set 15 | oga
# Processing Record 19 of Set 15 | naron
# Processing Record 20 of Set 15 | ankang
# Processing Record 21 of Set 15 | maniwaki
# Processing Record 22 of Set 15 | itanhem
# Processing Record 23 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 15 | hervey bay
# Processing Record 26 of Set 15 | kamennomostskiy
# Processing Record 27 of Set 15 | cascais
# Processing Record 28 of Set 15 | pitimbu
# Processing Record 29 of Set 15 | siderno
# Processing Record 30 of Set 15 | woodward
# Processing Record 31 of Set 15 | devils lake
# Processing Record 32 of Set 15 | diamantino
# Processing Record 33 of Set 15 | vozhd proletariata
# City not found. Skipping...
# Processing Record 34 of Set 15 | tezu
# Processing Record 35 of Set 15 | schwanewede
# Processing Record 36 of Set 15 | saint-georges
# Processing Record 37 of Set 15 | pacific grove
# Processing Record 38 of Set 15 | kontagora
# Processing Record 39 of Set 15 | lukovetskiy
# Processing Record 40 of Set 15 | tynda
# Processing Record 41 of Set 15 | markala
# Processing Record 42 of Set 15 | kopayhorod
# Processing Record 43 of Set 15 | wanning
# Processing Record 44 of Set 15 | antalaha
# Processing Record 45 of Set 15 | grand baie
# Processing Record 46 of Set 15 | san fernando
# Processing Record 47 of Set 15 | datong
# Processing Record 48 of Set 15 | kasama
# Processing Record 49 of Set 15 | leshan
# Processing Record 50 of Set 15 | porto novo
# Processing Record 1 of Set 16 | novorudnyy
# Processing Record 2 of Set 16 | viana
# Processing Record 3 of Set 16 | bandarbeyla
# Processing Record 4 of Set 16 | anori
# Processing Record 5 of Set 16 | trabzon
# Processing Record 6 of Set 16 | hiriyur
# Processing Record 7 of Set 16 | sabang
# Processing Record 8 of Set 16 | victor harbor
# Processing Record 9 of Set 16 | basco
# Processing Record 10 of Set 16 | gayny
# Processing Record 11 of Set 16 | lensk
# Processing Record 12 of Set 16 | monte patria
# Processing Record 13 of Set 16 | alihe
# Processing Record 14 of Set 16 | shitanjing
# Processing Record 15 of Set 16 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 16 | erzin
# Processing Record 17 of Set 16 | damghan
# Processing Record 18 of Set 16 | aksarayskiy
# Processing Record 19 of Set 16 | hay river
# Processing Record 20 of Set 16 | mao
# Processing Record 21 of Set 16 | naica
# Processing Record 22 of Set 16 | tabou
# Processing Record 23 of Set 16 | jiwani
# Processing Record 24 of Set 16 | middelburg
# Processing Record 25 of Set 16 | kyabram
# Processing Record 26 of Set 16 | veraval
# Processing Record 27 of Set 16 | midyat
# Processing Record 28 of Set 16 | sao felipe
# Processing Record 29 of Set 16 | morlaix
# Processing Record 30 of Set 16 | hambantota
# Processing Record 31 of Set 16 | antsohihy
# Processing Record 32 of Set 16 | luoyang
# Processing Record 33 of Set 16 | karpogory
# Processing Record 34 of Set 16 | qazvin
# Processing Record 35 of Set 16 | la romana
# Processing Record 36 of Set 16 | sungaipenuh
# Processing Record 37 of Set 16 | sozimskiy
# Processing Record 38 of Set 16 | masallatah
# Processing Record 39 of Set 16 | port harcourt
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cidreira      BR -30.1811  -50.2056     48.76        63           6
# 1         Hermanus      ZA -34.4187   19.2345     61.81        46          66
# 2             Lasa      IT  46.6166   10.7002     65.28        79           0
# 3     Puerto Ayora      EC  -0.7393  -90.3518     76.96        92          53
# 4           Hobart      AU -42.8794  147.3294     40.86        78          40
# 5         Sisimiut      GL  66.9395  -53.6735     41.86        69          30
# 6            Bluff      NZ -46.6000  168.3333     39.79        77         100
# 7      Belaya Gora      RU  68.5333  146.4167     65.70        38           1
# 8           Barrow      US  71.2906 -156.7887     32.02        80         100
# 9  Bambous Virieux      MU -20.3428   57.7575     68.25        94          75
#
#    Wind Speed Current Description
# 0       18.16           clear sky
# 1        7.29       broken clouds
# 2        4.99           clear sky
# 3        8.01       broken clouds
# 4       17.27    scattered clouds
# 5       13.96    scattered clouds
# 6       10.27     overcast clouds
# 7       11.72           clear sky
# 8       12.66     overcast clouds
# 9        3.44          light rain

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label = "City_ID")
